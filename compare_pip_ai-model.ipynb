# %%
import xarray as xr
import os
import numpy as np
import sys
import json
from datetime import datetime
from time import sleep


import cartopy.crs as ccrs
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import climetlab as cml
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import climetlab as cml
#
# ModuleNotFoundError: No module named 'climetlab'

# %%
# air = xr.open_mfdataset("/mnt/V/Master/climate/skillscores/sfno/20240131-1721/rmse_global*")

# %%
sfno_pip_tcwv = xr.open_dataset("/mnt/V/Master/ai-models/sfno_2019_744forcastentireAtmosphere.grb")["tcwv"]
fcn_pip_tcwv = xr.open_dataset("/mnt/V/Master/ai-models/fourcastnet_2019_744forcast_entireAtmosphere.grb")["tcwv"]

# %%
sfno_pip_u10 = xr.open_dataset("/mnt/V/Master/ai-models/sfno_2019_744forcastheightAboveGround.grb")["u10"]
fcn_pip_u10 = xr.open_dataset("/mnt/V/Master/ai-models/fourcastnet_2019_744forcast_heightAboveGround.grb")["u10"]
# Out:
# skipping variable: paramId==228246 shortName='u100'
# Traceback (most recent call last):
#   File "/home/lenny/miniconda3/envs/weather/lib/python3.12/site-packages/cfgrib/dataset.py", line 680, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "/home/lenny/miniconda3/envs/weather/lib/python3.12/site-packages/cfgrib/dataset.py", line 611, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='heightAboveGround' value=Variable(dimensions=(), data=10.0) new_value=Variable(dimensions=(), data=100.0)
# skipping variable: paramId==228247 shortName='v100'
# Traceback (most recent call last):
#   File "/home/lenny/miniconda3/envs/weather/lib/python3.12/site-packages/cfgrib/dataset.py", line 680, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "/home/lenny/miniconda3/envs/weather/lib/python3.12/site-packages/cfgrib/dataset.py", line 611, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='heightAboveGround' value=Variable(dimensions=(), data=10.0) new_value=Variable(dimensions=(), data=100.0)
# skipping variable: paramId==167 shortName='t2m'
# Traceback (most recent call last):
#   File "/home/lenny/miniconda3/envs/weather/lib/python3.12/site-packages/cfgrib/dataset.py", line 680, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "/home/lenny/miniconda3/envs/weather/lib/python3.12/site-packages/cfgrib/dataset.py", line 611, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='heightAboveGround' value=Variable(dimensions=(), data=10.0) new_value=Variable(dimensions=(), data=2.0)
# skipping variable: paramId==167 shortName='t2m'
# Traceback (most recent call last):
#   File "/home/lenny/miniconda3/envs/weather/lib/python3.12/site-packages/cfgrib/dataset.py", line 680, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "/home/lenny/miniconda3/envs/weather/lib/python3.12/site-packages/cfgrib/dataset.py", line 611, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='heightAboveGround' value=Variable(dimensions=(), data=10.0) new_value=Variable(dimensions=(), data=2.0)
# skipping variable: paramId==228246 shortName='u100'
# Traceback (most recent call last):
#   File "/home/lenny/miniconda3/envs/weather/lib/python3.12/site-packages/cfgrib/dataset.py", line 680, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "/home/lenny/miniconda3/envs/weather/lib/python3.12/site-packages/cfgrib/dataset.py", line 611, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='heightAboveGround' value=Variable(dimensions=(), data=10.0) new_value=Variable(dimensions=(), data=100.0)
# skipping variable: paramId==228247 shortName='v100'
# Traceback (most recent call last):
#   File "/home/lenny/miniconda3/envs/weather/lib/python3.12/site-packages/cfgrib/dataset.py", line 680, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "/home/lenny/miniconda3/envs/weather/lib/python3.12/site-packages/cfgrib/dataset.py", line 611, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='heightAboveGround' value=Variable(dimensions=(), data=10.0) new_value=Variable(dimensions=(), data=100.0)

# %%
sfno_model = xr.open_mfdataset("/mnt/ssd2/Master/S2S_on_SFNO/outputs/sfno/leadtime_8760_startDate_201901010_createdOn_20240129T2243/leadtime_8760_startDate_201901010_createdOn_20240129T2243_step_*")
fcn_model = xr.open_mfdataset("/mnt/ssd2/Master/S2S_on_SFNO/outputs/fourcastnet/leadtime_8760_startDate_201901010_createdOn_20240129T2244/leadtime_8760_startDate_201901010_createdOn_20240129T2244_step_*")

# %%
sfno_model_tcwv = sfno_model["tcwv"].sel(step=slice(np.timedelta64(0,'D'), np.timedelta64(31,'D')))
fcn_model_tcwv = fcn_model["tcwv"].sel(step=slice(np.timedelta64(0,'D'), np.timedelta64(31,'D')))
sfno_model_u10 = sfno_model["10u"].sel(step=slice(np.timedelta64(0,'D'), np.timedelta64(31,'D')))
fcn_model_u10 = fcn_model["10u"].sel(step=slice(np.timedelta64(0,'D'), np.timedelta64(31,'D')))

# %%
# sfno_model_tcwv_ = sfno_model_tcwv.sel(step=slice(np.timedelta64(0,'D'), np.timedelta64(31,'D')))
# fcn_model_tcwv_sel = fcn_model_tcwv.sel(step=slice(np.timedelta64(0,'D'), np.timedelta64(31,'D')))

# %%
# sfno_model_u10_sel  = sfno_model_u10.sel(step=slice(np.timedelta64(0,'D'), np.timedelta64(31,'D')))
# fcn_model_u10_sel = fcn_model_u10.sel(step=slice(np.timedelta64(0,'D'), np.timedelta64(31,'D')))

# %%
sfno_pip_tcwv
# Out:
# <xarray.DataArray 'tcwv' (step: 124, latitude: 721, longitude: 1440)>
# [128741760 values with dtype=float32]
# Coordinates:
#     time              datetime64[ns] ...
#   * step              (step) timedelta64[ns] 0 days 06:00:00 ... 31 days 00:0...
#     entireAtmosphere  float64 ...
#   * latitude          (latitude) float64 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude         (longitude) float64 0.0 0.25 0.5 ... 359.2 359.5 359.8
#     valid_time        (step) datetime64[ns] ...
# Attributes: (12/29)
#     GRIB_paramId:                             137
#     GRIB_dataType:                            fc
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         entireAtmosphere
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_name:                                Total column vertically-integra...
#     GRIB_shortName:                           tcwv
#     GRIB_units:                               kg m**-2
#     long_name:                                Total column vertically-integra...
#     units:                                    kg m**-2
#     standard_name:                            lwe_thickness_of_atmosphere_mas...

# %%
sfno_model_tcwv
# Out:
# <xarray.DataArray 'tcwv' (step: 124, latitude: 721, longitude: 1440)>
# dask.array<getitem, shape=(124, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude   (latitude) float64 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * longitude  (longitude) float64 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * step       (step) timedelta64[ns] 0 days 06:00:00 ... 31 days 00:00:00

# %%
sfno_pip_tcwv.equals(sfno_pip_tcwv)
# Out:
# True

# %%
1/sfno_model_tcwv.size*np.sum(np.abs(sfno_pip_tcwv - sfno_model_tcwv)).values
# Out:
# 0.2977259282458155

# %%
sfno_pip_tcwv.shape
# Out:
# (124, 721, 1440)

# %%
diff2 = np.abs(sfno_pip_tcwv - sfno_model_tcwv)

# %%
diff = sfno_pip_tcwv.sel(step=np.timedelta64(3,'D')) - sfno_model_tcwv.sel(step=np.timedelta64(3,'D'))

# %%
ax = plt.axes(projection=ccrs.Orthographic(-80, 35))
ax.set_global()
sfno_pip_tcwv.sel(step=np.timedelta64(3,'D')).plot.contourf(ax=ax, transform=ccrs.PlateCarree())
ax.coastlines()

# %%
ax = plt.axes(projection=ccrs.Orthographic(-80, 35))
ax.set_global()
sfno_model_tcwv.sel(step=np.timedelta64(3,'D')).plot.contourf(ax=ax, transform=ccrs.PlateCarree())
ax.coastlines()

# %%
a = diff.to_numpy()
plt.imshow(a)

# %%
ax = plt.axes(projection=ccrs.Orthographic(-80, 35))
ax.set_global()
diff2.sel(step=np.timedelta64(3,'D')).plot.contourf(ax=ax, transform=ccrs.PlateCarree())
ax.coastlines()

# %%
st3 = air.sel(step=[6*10])['rmse'].squeeze()

ax = plt.axes(projection=ccrs.Orthographic(-80, 35))
ax.set_global()
st3.plot.contourf(ax=ax, transform=ccrs.PlateCarree())
ax.coastlines()

# %%
st3 = air.sel(step=[294])['rmse'].squeeze()

ax = plt.axes(projection=ccrs.Orthographic(-80, 35))
ax.set_global()
st3.plot.contourf(ax=ax, transform=ccrs.PlateCarree())
ax.coastlines()

# %%
x = cml.load_source("file","/mnt/qb/goswami/data/era5/single_pressure_level/2m_temperature/2m_temperature_2021.nc")

# %%
y = x.sel(time="2021-01-01")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 y = x.sel(time="2021-01-01")
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/climetlab/sources/file.py:86, in FileSource.sel(self, *args, **kwargs)
#      85 def sel(self, *args, **kwargs):
# ---> 86     return self._reader.sel(*args, **kwargs)
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/climetlab/core/__init__.py:110, in Base.sel(self, *args, **kwargs)
#     108 @abstractmethod
#     109 def sel(self, *args, **kwargs):
# --> 110     self._not_implemented()
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/climetlab/core/__init__.py:196, in Base._not_implemented(self)
#     194 if hasattr(self, "path"):
#     195     extra = f" on {self.path}"
# --> 196 raise NotImplementedError(f"{module}.{name}.{func}(){extra}")
#
# NotImplementedError: climetlab.readers.netcdf.NetCDFReader.sel() on /mnt/qb/goswami/data/era5/single_pressure_level/2m_temperature/2m_temperature_2021.nc

# %%
t = xr.open_mfdataset(['/mnt/qb/goswami/data/era5/single_pressure_level/2m_temperature/2m_temperature_2019.nc',
                       '/mnt/qb/goswami/data/era5/single_pressure_level/10m_v_component_of_wind/10m_v_component_of_wind_2019.nc',
                      '/mnt/qb/goswami/data/era5/multi_pressure_level/v_component_of_wind/150/v_component_of_wind_2019_150.nc'],parallel=True)
# some end in 2019

# %%
t.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	longitude = 1440 ;
# 	latitude = 721 ;
# 	time = 8760 ;
#
# variables:
# 	float32 longitude(longitude) ;
# 		longitude:units = degrees_east ;
# 		longitude:long_name = longitude ;
# 	float32 latitude(latitude) ;
# 		latitude:units = degrees_north ;
# 		latitude:long_name = latitude ;
# 	datetime64[ns] time(time) ;
# 		time:long_name = time ;
# 	float32 t2m(time, latitude, longitude) ;
# 		t2m:units = K ;
# 		t2m:long_name = 2 metre temperature ;
# 	float32 v(time, latitude, longitude) ;
# 		v:units = m s**-1 ;
# 		v:long_name = V component of wind ;
# 		v:standard_name = northward_wind ;
# 	float32 v10(time, latitude, longitude) ;
# 		v10:units = m s**-1 ;
# 		v10:long_name = 10 metre V wind component ;
#
# // global attributes:
# 	:Conventions = CF-1.6 ;
# 	:history = 2022-07-30 20:50:57 GMT by grib_to_netcdf-2.25.1: /opt/ecmwf/mars-client/bin/grib_to_netcdf.bin -S param -o /cache/data5/adaptor.mars.internal-1659213908.3812256-27100-9-fd81b27d-ffca-4e74-af70-5c5a1c575091.nc /cache/tmp/fd81b27d-ffca-4e74-af70-5c5a1c575091-adaptor.mars.internal-1659213498.0593984-27100-14-tmp.grib ;
# }

# %%
time = datetime(2019,1,1,2)
test = t.sel(time=time)

# %%
n = test.to_array()

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# False

# %%
nump = n.to_numpy()

# %%
variable = '2m_temperature'
basePath = "/mnt/qb/work2/goswami0/gkd965/"
mean_file = os.path.join(basePath,"climate","hourofyear_mean_for_"+variable+"_from_1979_to_2019created_20231206-1713.nc")
model_file_sfno = os.path.join(basePath,'outputs','v10_SFNO_HalfYearForecast_startfrom_2021-01-01.nc')
model_file_fcn = os.path.join(basePath,'outputs','v10_FCN_HalfYearForecast_startfrom_2021-01-01.nc')
save_file = os.path.join(basePath,'')
dataPath = os.path.join("/mnt/qb/goswami/data/era5","single_pressure_level",variable,variable+"_{}.nc")

ds_sfno = xr.open_dataset(model_file_sfno).to_array().squeeze()
ds_fcn = xr.open_dataset(model_file_fcn).to_array().squeeze()
ds_ref  = xr.open_dataset(mean_file).to_array().squeeze()[:ds_sfno.dims["step"]*6:6]
g_truth = xr.open_dataset(dataPath.format(2021)).to_array().squeeze()[:ds_sfno.dims["step"]*6:6]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/envs/model/lib/python3.11/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/mnt/qb/work2/goswami0/gkd965/outputs/v10_SFNO_HalfYearForecast_startfrom_2021-01-01.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'ec583a53-87d6-4de5-9d77-034119aa38ee']
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 9
#       6 save_file = os.path.join(basePath,'')
#       7 dataPath = os.path.join("/mnt/qb/goswami/data/era5","single_pressure_level",variable,variable+"_{}.nc")
# ----> 9 ds_sfno = xr.open_dataset(model_file_sfno).to_array().squeeze()
#      10 ds_fcn = xr.open_dataset(model_file_sfno).to_array().squeeze()
#      11 ds_ref  = xr.open_dataset(mean_file).to_array().squeeze()[:ds_sfno.dims["step"]*6:6]
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/xarray/backends/api.py:572, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     560 decoders = _resolve_decoders_kwargs(
#     561     decode_cf,
#     562     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     568     decode_coords=decode_coords,
#     569 )
#     571 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 572 backend_ds = backend.open_dataset(
#     573     filename_or_obj,
#     574     drop_variables=drop_variables,
#     575     **decoders,
#     576     **kwargs,
#     577 )
#     578 ds = _dataset_from_backend_dataset(
#     579     backend_ds,
#     580     filename_or_obj,
#    (...)
#     590     **kwargs,
#     591 )
#     592 return ds
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:593, in NetCDF4BackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, lock, autoclose)
#     572 def open_dataset(  # type: ignore[override]  # allow LSP violation, not supporting **kwargs
#     573     self,
#     574     filename_or_obj: str | os.PathLike[Any] | BufferedIOBase | AbstractDataStore,
#    (...)
#     590     autoclose=False,
#     591 ) -> Dataset:
#     592     filename_or_obj = _normalize_path(filename_or_obj)
# --> 593     store = NetCDF4DataStore.open(
#     594         filename_or_obj,
#     595         mode=mode,
#     596         format=format,
#     597         group=group,
#     598         clobber=clobber,
#     599         diskless=diskless,
#     600         persist=persist,
#     601         lock=lock,
#     602         autoclose=autoclose,
#     603     )
#     605     store_entrypoint = StoreBackendEntrypoint()
#     606     with close_on_error(store):
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:400, in NetCDF4DataStore.open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     394 kwargs = dict(
#     395     clobber=clobber, diskless=diskless, persist=persist, format=format
#     396 )
#     397 manager = CachingFileManager(
#     398     netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     399 )
# --> 400 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:347, in NetCDF4DataStore.__init__(self, manager, group, mode, lock, autoclose)
#     345 self._group = group
#     346 self._mode = mode
# --> 347 self.format = self.ds.data_model
#     348 self._filename = self.ds.filepath()
#     349 self.is_remote = is_remote_uri(self._filename)
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:409, in NetCDF4DataStore.ds(self)
#     407 @property
#     408 def ds(self):
# --> 409     return self._acquire()
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:403, in NetCDF4DataStore._acquire(self, needs_lock)
#     402 def _acquire(self, needs_lock=True):
# --> 403     with self._manager.acquire_context(needs_lock) as root:
#     404         ds = _nc4_require_group(root, self._group, self._mode)
#     405     return ds
#
# File /opt/conda/envs/model/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/xarray/backends/file_manager.py:199, in CachingFileManager.acquire_context(self, needs_lock)
#     196 @contextlib.contextmanager
#     197 def acquire_context(self, needs_lock=True):
#     198     """Context manager for acquiring a file."""
# --> 199     file, cached = self._acquire_with_cache_info(needs_lock)
#     200     try:
#     201         yield file
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/xarray/backends/file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File src/netCDF4/_netCDF4.pyx:2469, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:2028, in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/qb/work2/goswami0/gkd965/outputs/v10_SFNO_HalfYearForecast_startfrom_2021-01-01.nc'

# %%
basePath = "/mnt/qb/work2/goswami0/gkd965/climate/"
basePath_data = "/mnt/qb/goswami/data/era5"

# %%
d1 = xr.open_dataset(os.path.join(basePath,"mean_for_loop_numpy_4years.nc"))
d2 = xr.open_dataset(os.path.join(basePath,"mean_for_loop_xarray_4years.nc"))
d3 = xr.open_dataset(os.path.join(basePath,"mean_for_loop_xarray_4years2.nc"))

o1 = xr.open_dataset(os.path.join(basePath_data, 'single_pressure_level', '10m_v_component_of_wind', "10m_v_component_of_wind_1990.nc"))
o2 = xr.open_dataset(os.path.join(basePath_data, 'single_pressure_level', '10m_v_component_of_wind', "10m_v_component_of_wind_1991.nc"))
o22 = xr.open_dataset(os.path.join(basePath_data, 'single_pressure_level', '10m_v_component_of_wind', "10m_v_component_of_wind_1992.nc"))
o3 = xr.open_dataset(os.path.join(basePath_data, 'single_pressure_level', '10m_v_component_of_wind', "10m_v_component_of_wind_1993.nc"))
# d3 = xr.open_dataset(os.path.join(basePath,"mean_for_loop_numpy_4years.nc")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 d1 = xr.open_dataset(os.path.join(basePath,"mean_for_loop_numpy_4years.nc"))
#       2 d2 = xr.open_dataset(os.path.join(basePath,"mean_for_loop_xarray_4years.nc"))
# ----> 3 d3 = xr.open_dataset(os.path.join(basePath,"mean_for_loop_xarray_4years2.nc"))
#       5 o1 = xr.open_dataset(os.path.join(basePath_data, 'single_pressure_level', '10m_v_component_of_wind', "10m_v_component_of_wind_1990.nc"))
#       6 o2 = xr.open_dataset(os.path.join(basePath_data, 'single_pressure_level', '10m_v_component_of_wind', "10m_v_component_of_wind_1991.nc"))
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/xarray/backends/api.py:553, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     550     kwargs.update(backend_kwargs)
#     552 if engine is None:
# --> 553     engine = plugins.guess_engine(filename_or_obj)
#     555 if from_array_kwargs is None:
#     556     from_array_kwargs = {}
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/xarray/backends/plugins.py:197, in guess_engine(store_spec)
#     189 else:
#     190     error_msg = (
#     191         "found the following matches with the input file in xarray's IO "
#     192         f"backends: {compatible_engines}. But their dependencies may not be installed, see:\n"
#     193         "https://docs.xarray.dev/en/stable/user-guide/io.html \n"
#     194         "https://docs.xarray.dev/en/stable/getting-started-guide/installing.html"
#     195     )
# --> 197 raise ValueError(error_msg)
#
# ValueError: did not find a match in any of xarray's currently installed IO backends ['netcdf4', 'h5netcdf', 'scipy', 'cfgrib', 'zarr']. Consider explicitly selecting one of the installed engines via the ``engine`` parameter, or installing additional IO dependencies, see:
# https://docs.xarray.dev/en/stable/getting-started-guide/installing.html
# https://docs.xarray.dev/en/stable/user-guide/io.html

# %%
o22.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	longitude = 1440 ;
# 	latitude = 721 ;
# 	time = 8784 ;
#
# variables:
# 	float32 longitude(longitude) ;
# 		longitude:units = degrees_east ;
# 		longitude:long_name = longitude ;
# 	float32 latitude(latitude) ;
# 		latitude:units = degrees_north ;
# 		latitude:long_name = latitude ;
# 	datetime64[ns] time(time) ;
# 		time:long_name = time ;
# 	float32 v10(time, latitude, longitude) ;
# 		v10:units = m s**-1 ;
# 		v10:long_name = 10 metre V wind component ;
#
# // global attributes:
# 	:Conventions = CF-1.6 ;
# 	:history = 2022-07-14 21:40:06 GMT by grib_to_netcdf-2.25.1: /opt/ecmwf/mars-client/bin/grib_to_netcdf.bin -S param -o /cache/data1/adaptor.mars.internal-1657834392.3566024-31024-17-23fb2092-6bb1-4966-9993-34af0dca5940.nc /cache/tmp/23fb2092-6bb1-4966-9993-34af0dca5940-adaptor.mars.internal-1657833904.5421054-31024-25-tmp.grib ;
# }

# %%
o222  = o22.drop_isel(time=list(range((31+28)*24,(31+29)*24)))

# %%
o222.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	longitude = 1440 ;
# 	latitude = 721 ;
# 	time = 8760 ;
#
# variables:
# 	float32 longitude(longitude) ;
# 		longitude:units = degrees_east ;
# 		longitude:long_name = longitude ;
# 	float32 latitude(latitude) ;
# 		latitude:units = degrees_north ;
# 		latitude:long_name = latitude ;
# 	datetime64[ns] time(time) ;
# 		time:long_name = time ;
# 	float32 v10(time, latitude, longitude) ;
# 		v10:units = m s**-1 ;
# 		v10:long_name = 10 metre V wind component ;
#
# // global attributes:
# 	:Conventions = CF-1.6 ;
# 	:history = 2022-07-14 21:40:06 GMT by grib_to_netcdf-2.25.1: /opt/ecmwf/mars-client/bin/grib_to_netcdf.bin -S param -o /cache/data1/adaptor.mars.internal-1657834392.3566024-31024-17-23fb2092-6bb1-4966-9993-34af0dca5940.nc /cache/tmp/23fb2092-6bb1-4966-9993-34af0dca5940-adaptor.mars.internal-1657833904.5421054-31024-25-tmp.grib ;
# }

# %%
d1.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	longitude = 8760 ;
# 	latitude = 721 ;
# 	time = 1440 ;
#
# variables:
# 	float32 v10(longitude, latitude, time) ;
#
# // global attributes:
# }

# %%
print(d1.isel(longitude=10,latitude=10,time=100).load())
# Out:
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     v10      float32 -3.14

# %%
print(d2.isel(longitude=10,latitude=10,time=100).load())
# Out:
# <xarray.Dataset>
# Dimensions:                        ()
# Coordinates:
#     longitude                      float32 2.5
#     latitude                       float32 87.5
#     time                           int64 0
#     variable                       <U3 'v10'
# Data variables:
#     __xarray_dataarray_variable__  float32 -6.085

# %%
print(d3.isel(longitude=10,latitude=10,time=100).load())
# Out:
# <xarray.Dataset>
# Dimensions:                        ()
# Coordinates:
#     longitude                      float32 2.5
#     latitude                       float32 87.5
#     time                           int64 100
#     variable                       <U3 'v10'
# Data variables:
#     __xarray_dataarray_variable__  float32 3.557

# %%
print(o1.isel(longitude=10,latitude=10,time=100).load())
# Out:
# <xarray.Dataset>
# Dimensions:    ()
# Coordinates:
#     longitude  float32 2.5
#     latitude   float32 87.5
#     time       datetime64[ns] 1990-01-05T04:00:00
# Data variables:
#     v10        float32 5.748
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-07-14 20:34:17 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
print(o2.isel(longitude=10,latitude=10,time=100).load())
# Out:
# <xarray.Dataset>
# Dimensions:    ()
# Coordinates:
#     longitude  float32 2.5
#     latitude   float32 87.5
#     time       datetime64[ns] 1991-01-05T04:00:00
# Data variables:
#     v10        float32 -2.989
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-07-14 21:08:34 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
print(o3.isel(longitude=10,latitude=10,time=100).load())
# Out:
# <xarray.Dataset>
# Dimensions:    ()
# Coordinates:
#     longitude  float32 2.5
#     latitude   float32 87.5
#     time       datetime64[ns] 1993-01-05T04:00:00
# Data variables:
#     v10        float32 0.8282
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-07-14 22:06:55 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
(0.8282 + 5.748 - 2.989)/3
(5.748 - 2.989)/2
# Out:
# 1.3795000000000002

# %%
basePath = "/mnt/qb/goswami/data/era5"
v10_1 = xr.open_dataset(os.path.join(basePath, 'single_pressure_level', '10m_v_component_of_wind', "10m_v_component_of_wind_1992.nc"))
v10_2 = xr.open_dataset(os.path.join(basePath, 'single_pressure_level', '10m_v_component_of_wind', "10m_v_component_of_wind_1991.nc"))

# %%
timesteps1 = v10_1.dims["time"]   
timesteps2 = v10_2.dims["time"]   
print(timesteps1)
print(timesteps2)
# Out:
# 8784
# 8760

# %%
v10_1.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	longitude = 1440 ;
# 	latitude = 721 ;
# 	time = 8784 ;
#
# variables:
# 	float32 longitude(longitude) ;
# 		longitude:units = degrees_east ;
# 		longitude:long_name = longitude ;
# 	float32 latitude(latitude) ;
# 		latitude:units = degrees_north ;
# 		latitude:long_name = latitude ;
# 	datetime64[ns] time(time) ;
# 		time:long_name = time ;
# 	float32 v10(time, latitude, longitude) ;
# 		v10:units = m s**-1 ;
# 		v10:long_name = 10 metre V wind component ;
#
# // global attributes:
# 	:Conventions = CF-1.6 ;
# 	:history = 2022-07-14 21:40:06 GMT by grib_to_netcdf-2.25.1: /opt/ecmwf/mars-client/bin/grib_to_netcdf.bin -S param -o /cache/data1/adaptor.mars.internal-1657834392.3566024-31024-17-23fb2092-6bb1-4966-9993-34af0dca5940.nc /cache/tmp/23fb2092-6bb1-4966-9993-34af0dca5940-adaptor.mars.internal-1657833904.5421054-31024-25-tmp.grib ;
# }

# %%
year=1992
# v10_1_drop = v10_1.drop_sel(time=slice(str(year)+"-02-29",str(year)+"-03-01"))
v10_1_drop = v10_1.where((v10_1["time"] == "1990-02-29") | (v10_1["time"] > 2000), drop=True)
v10_1_drop.dims["time"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 year=1992
# ----> 2 v10_1_drop = v10_1.drop_sel(time=slice(str(year)+"-02-29",str(year)+"-03-01"))
#       3 v10_1_drop.dims["time"]
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/xarray/core/dataset.py:6039, in Dataset.drop_sel(self, labels, errors, **labels_kwargs)
#    6037     except KeyError:
#    6038         raise ValueError(f"dimension {dim!r} does not have coordinate labels")
# -> 6039     new_index = index.drop(labels_for_dim, errors=errors)
#    6040     ds = ds.loc[{dim: new_index}]
#    6041 return ds
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/pandas/core/indexes/base.py:6988, in Index.drop(self, labels, errors)
#    6985     arr_dtype = "object" if self.dtype == "object" else None
#    6986     labels = com.index_labels_to_array(labels, dtype=arr_dtype)
# -> 6988 indexer = self.get_indexer_for(labels)
#    6989 mask = indexer == -1
#    6990 if mask.any():
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/pandas/core/indexes/base.py:6096, in Index.get_indexer_for(self, target)
#    6078 """
#    6079 Guaranteed return of an indexer even when non-unique.
#    6080
#    (...)
#    6093 array([0, 2])
#    6094 """
#    6095 if self._index_as_unique:
# -> 6096     return self.get_indexer(target)
#    6097 indexer, _ = self.get_indexer_non_unique(target)
#    6098 return indexer
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/pandas/core/indexes/base.py:3938, in Index.get_indexer(self, target, method, limit, tolerance)
#    3936     this = self.astype(dtype, copy=False)
#    3937     target = target.astype(dtype, copy=False)
# -> 3938     return this._get_indexer(
#    3939         target, method=method, limit=limit, tolerance=tolerance
#    3940     )
#    3942 return self._get_indexer(target, method, limit, tolerance)
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/pandas/core/indexes/base.py:3969, in Index._get_indexer(self, target, method, limit, tolerance)
#    3966     else:
#    3967         tgt_values = target._get_engine_target()
# -> 3969     indexer = self._engine.get_indexer(tgt_values)
#    3971 return ensure_platform_int(indexer)
#
# File index.pyx:336, in pandas._libs.index.IndexEngine.get_indexer()
#
# File pandas/_libs/hashtable_class_helper.pxi:7131, in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# TypeError: unhashable type: 'slice'

# %%
v10_1.where(v10_1["time"] == "1992-02-29")

# %%
v10_1.sel(time="1992-02-29")
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 1440, latitude: 721, time: 24)
# Coordinates:
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 1992-02-29 ... 1992-02-29T23:00:00
# Data variables:
#     v10        (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-07-14 21:40:06 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
t = v10_1.sel(time="1992-02-29")

# %%
v10_1.isel(time=(31+28)*24)
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 1440, latitude: 721)
# Coordinates:
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#     time       datetime64[ns] 1992-02-29
# Data variables:
#     v10        (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-07-14 21:40:06 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
droped = v10_1.drop_isel(time=list(range((31+28)*24,(31+29)*24)))

# %%
droped.dims["time"]
# Out:
# 8760

# %%
v10_2.isel(time=(31+28)*24)
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 1440, latitude: 721)
# Coordinates:
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#     time       datetime64[ns] 1991-03-01
# Data variables:
#     v10        (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-07-14 21:08:34 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
t.dims["time"]
# Out:
# 8783

# %%
print(t.sel(time="1992-02").coords["time"].to_numpy())
# Out:
# ['1992-02-01T00:00:00.000000000' '1992-02-01T01:00:00.000000000'
#  '1992-02-01T02:00:00.000000000' '1992-02-01T03:00:00.000000000'
#  '1992-02-01T04:00:00.000000000' '1992-02-01T05:00:00.000000000'
#  '1992-02-01T06:00:00.000000000' '1992-02-01T07:00:00.000000000'
#  '1992-02-01T08:00:00.000000000' '1992-02-01T09:00:00.000000000'
#  '1992-02-01T10:00:00.000000000' '1992-02-01T11:00:00.000000000'
#  '1992-02-01T12:00:00.000000000' '1992-02-01T13:00:00.000000000'
#  '1992-02-01T14:00:00.000000000' '1992-02-01T15:00:00.000000000'
#  '1992-02-01T16:00:00.000000000' '1992-02-01T17:00:00.000000000'
#  '1992-02-01T18:00:00.000000000' '1992-02-01T19:00:00.000000000'
#  '1992-02-01T20:00:00.000000000' '1992-02-01T21:00:00.000000000'
#  '1992-02-01T22:00:00.000000000' '1992-02-01T23:00:00.000000000'
#  '1992-02-02T00:00:00.000000000' '1992-02-02T01:00:00.000000000'
#  '1992-02-02T02:00:00.000000000' '1992-02-02T03:00:00.000000000'
#  '1992-02-02T04:00:00.000000000' '1992-02-02T05:00:00.000000000'
#  '1992-02-02T06:00:00.000000000' '1992-02-02T07:00:00.000000000'
#  '1992-02-02T08:00:00.000000000' '1992-02-02T09:00:00.000000000'
#  '1992-02-02T10:00:00.000000000' '1992-02-02T11:00:00.000000000'
#  '1992-02-02T12:00:00.000000000' '1992-02-02T13:00:00.000000000'
#  '1992-02-02T14:00:00.000000000' '1992-02-02T15:00:00.000000000'
#  '1992-02-02T16:00:00.000000000' '1992-02-02T17:00:00.000000000'
#  '1992-02-02T18:00:00.000000000' '1992-02-02T19:00:00.000000000'
#  '1992-02-02T20:00:00.000000000' '1992-02-02T21:00:00.000000000'
#  '1992-02-02T22:00:00.000000000' '1992-02-02T23:00:00.000000000'
#  '1992-02-03T00:00:00.000000000' '1992-02-03T01:00:00.000000000'
#  '1992-02-03T02:00:00.000000000' '1992-02-03T03:00:00.000000000'
#  '1992-02-03T04:00:00.000000000' '1992-02-03T05:00:00.000000000'
#  '1992-02-03T06:00:00.000000000' '1992-02-03T07:00:00.000000000'
#  '1992-02-03T08:00:00.000000000' '1992-02-03T09:00:00.000000000'
#  '1992-02-03T10:00:00.000000000' '1992-02-03T11:00:00.000000000'
#  '1992-02-03T12:00:00.000000000' '1992-02-03T13:00:00.000000000'
#  '1992-02-03T14:00:00.000000000' '1992-02-03T15:00:00.000000000'
#  '1992-02-03T16:00:00.000000000' '1992-02-03T17:00:00.000000000'
#  '1992-02-03T18:00:00.000000000' '1992-02-03T19:00:00.000000000'
#  '1992-02-03T20:00:00.000000000' '1992-02-03T21:00:00.000000000'
#  '1992-02-03T22:00:00.000000000' '1992-02-03T23:00:00.000000000'
#  '1992-02-26T22:00:00.000000000' '1992-02-26T23:00:00.000000000'
#  '1992-02-27T00:00:00.000000000' '1992-02-27T01:00:00.000000000'
#  '1992-02-27T02:00:00.000000000' '1992-02-27T03:00:00.000000000'
#  '1992-02-27T04:00:00.000000000' '1992-02-27T05:00:00.000000000'
#  '1992-02-27T06:00:00.000000000' '1992-02-27T07:00:00.000000000'
#  '1992-02-27T08:00:00.000000000' '1992-02-27T09:00:00.000000000'
#  '1992-02-27T10:00:00.000000000' '1992-02-27T11:00:00.000000000'
#  '1992-02-27T12:00:00.000000000' '1992-02-27T13:00:00.000000000'
#  '1992-02-27T14:00:00.000000000' '1992-02-27T15:00:00.000000000'
#  '1992-02-27T16:00:00.000000000' '1992-02-27T17:00:00.000000000'
#  '1992-02-27T18:00:00.000000000' '1992-02-27T19:00:00.000000000'
#  '1992-02-27T20:00:00.000000000' '1992-02-27T21:00:00.000000000'
#  '1992-02-27T22:00:00.000000000' '1992-02-27T23:00:00.000000000'
#  '1992-02-28T00:00:00.000000000' '1992-02-28T01:00:00.000000000'
#  '1992-02-28T02:00:00.000000000' '1992-02-28T03:00:00.000000000'
#  '1992-02-28T04:00:00.000000000' '1992-02-28T05:00:00.000000000'
#  '1992-02-28T06:00:00.000000000' '1992-02-28T07:00:00.000000000'
#  '1992-02-28T08:00:00.000000000' '1992-02-28T09:00:00.000000000'
#  '1992-02-28T10:00:00.000000000' '1992-02-28T11:00:00.000000000'
#  '1992-02-28T12:00:00.000000000' '1992-02-28T13:00:00.000000000'
#  '1992-02-28T14:00:00.000000000' '1992-02-28T15:00:00.000000000'
#  '1992-02-28T16:00:00.000000000' '1992-02-28T17:00:00.000000000'
#  '1992-02-28T18:00:00.000000000' '1992-02-28T19:00:00.000000000'
#  '1992-02-28T20:00:00.000000000' '1992-02-28T21:00:00.000000000'
#  '1992-02-28T22:00:00.000000000' '1992-02-28T23:00:00.000000000'
#  '1992-02-29T01:00:00.000000000' '1992-02-29T02:00:00.000000000'
#  '1992-02-29T03:00:00.000000000' '1992-02-29T04:00:00.000000000'
#  '1992-02-29T05:00:00.000000000' '1992-02-29T06:00:00.000000000'
#  '1992-02-29T07:00:00.000000000' '1992-02-29T08:00:00.000000000'
#  '1992-02-29T09:00:00.000000000' '1992-02-29T10:00:00.000000000'
#  '1992-02-29T11:00:00.000000000' '1992-02-29T12:00:00.000000000'
#  '1992-02-29T13:00:00.000000000' '1992-02-29T14:00:00.000000000'
#  '1992-02-29T15:00:00.000000000' '1992-02-29T16:00:00.000000000'
#  '1992-02-29T17:00:00.000000000' '1992-02-29T18:00:00.000000000'
#  '1992-02-29T19:00:00.000000000' '1992-02-29T20:00:00.000000000'
#  '1992-02-29T21:00:00.000000000' '1992-02-29T22:00:00.000000000'
#  '1992-02-29T23:00:00.000000000']

# %%
xr.align(v10_1,v10_2, join='exact')

# %%
basePath = "/mnt/qb/goswami/data/era5"
savepath = "/mnt/qb/work2/goswami0/gkd965/climate/chunky"
monitor_savepath = os.path.join(savepath,"monitor"+datetime.now().strftime("%Y%m%d-%H%M")+".json")
ds = xr.open_mfdataset(os.path.join(basePath, 'single_pressure_level', '10m_v_component_of_wind', "10m_v_component_of_wind_????.nc"),parallel=True)

work = [(lat,long) for lat in range(ds.sizes["latitude"]) for long in range(ds.sizes["longitude"])]

for lat, long in work:
    for year in range(1959,2022):
        for month in range(1,13):
            for day in range(1,32):
                if day == 31 and month in [2,4,6,9,11]:
                    continue
                if day == 30 and month == 2:
                    continue
                if day == 29 and month == 2 and year not in range(1948,2025,4):
                    continue
                for hour in range(0,24,6):
                    ds_lat_long = ds.sel(latitude=lat,longitude=long,time=datetime(year,month,day,hour,0),method='nearest')
                    ds_lat_long.info()
                    break
                break
            break
        break
    break
# Out:
# xarray.Dataset {
# dimensions:
#
# variables:
# 	float32 longitude() ;
# 		longitude:units = degrees_east ;
# 		longitude:long_name = longitude ;
# 	float32 latitude() ;
# 		latitude:units = degrees_north ;
# 		latitude:long_name = latitude ;
# 	datetime64[ns] time() ;
# 		time:long_name = time ;
# 	float32 v10() ;
# 		v10:units = m s**-1 ;
# 		v10:long_name = 10 metre V wind component ;
#
# // global attributes:
# 	:Conventions = CF-1.6 ;
# 	:history = 2022-07-14 14:01:09 GMT by grib_to_netcdf-2.25.1: /opt/ecmwf/mars-client/bin/grib_to_netcdf.bin -S param -o /cache/data1/adaptor.mars.internal-1657806762.467146-16033-8-e12dca0a-c8ec-405a-9f94-5781ea6dc0fe.nc /cache/tmp/e12dca0a-c8ec-405a-9f94-5781ea6dc0fe-adaptor.mars.internal-1657806279.235086-16033-9-tmp.grib ;
# }

# %%
import psutil

# %%
pid = os.getpid()
print(pid)
# Out:
# 43065

# %%
def system_monitor(printout=False,pids=[],names=[]):
    system = {}
    mem_percent = psutil.virtual_memory()[2]
    mem_used = psutil.virtual_memory()[3]/1000000000
    mem_total = psutil.virtual_memory()[1]/1000000000
    processes = []
    for i,pid in enumerate(pids):
        python_process = psutil.Process(pid)
        mem_proc = python_process.memory_percent()
        mem_proc_percent = python_process.memory_info()[0]/2.**30  # memory use in GB...I think
        processes.append({"pid":pid,"process":names[i],"memory percent":mem_proc,"memory used(GB)":mem_proc_percent})
    cores = os.cpu_count()
    cpu_percent = psutil.cpu_percent()
    loads = psutil.getloadavg()
    cpu_usage = [load/cores* 100 for load in loads]
    if printout:
        print("RAM:")
        print('    memory % used:', mem_percent)
        print('    Used (GB):', mem_used)
        print('    Total available (GB):', mem_total)
        # use memory_profiler  for line by line memory analysis, add @profile above function
        # Ram for certain process:
        print('    Process memory used (GB):', mem_proc)
        print("    Process memory used : ", mem_proc_percent)

        print("CPU:")
        print("    available cores: ",cores)
        print("    util: ",cpu_percent)
        print("    averge load over 1, 5 ,15 min: ",cpu_usage)
    
    system["memory percent"] =  mem_percent
    system["memory used(GB)"] =  mem_used
    system["memory total available (GB)"] =  mem_total
    system["processes"] =  processes
    system["cpu percent"] =  cpu_percent
    system["cpu usage"] =  cpu_usage
    system["cores"] =  cores

    return system

# %%
python_process = psutil.Process(pid)
mem_proc = python_process.memory_percent()
mem_proc_percent = python_process.memory_info()[0]/2.**30 

print('    Process memory used (GB):', mem_proc)
print("    Process memory used : ", mem_proc_percent)
# Out:
#     Process memory used (GB): 0.08955224939542299
#     Process memory used :  0.33704376220703125

# %%
# loded = ds.sel(time=slice(datetime(1990,1,1,0,0),datetime(1990,1,1,22,0))).load()
loaded2 = ds.sel(time=slice('1990-01-01', '1990-03-01')).load()

# %%
stats = system_monitor(True,[os.getpid()],["main"])
# Out:
# RAM:
#     memory % used: 5.9
#     Used (GB): 21.925208064
#     Total available (GB): 380.155244544
#     Process memory used (GB): 0.08955934432882462
#     Process memory used :  0.3370704650878906
# CPU:
#     available cores:  72
#     util:  6.0
#     averge load over 1, 5 ,15 min:  [6.916666666666667, 6.194444444444444, 6.180555555555555]

# %%
ds_lat_long_time = ds.sel(time=datetime(year,month,day,hour,0),method='nearest').load()

# %%
ds_loaded = ds.load()

# %%
stats = system_monitor(True,[os.getpid()],["main"])
# Out:
# RAM:
#     memory % used: 6.7
#     Used (GB): 24.971821056
#     Total available (GB): 377.108660224
#     Process memory used (GB): 0.8792791507121465
#     Process memory used :  3.3093032836914062
# CPU:
#     available cores:  72
#     util:  6.0
#     averge load over 1, 5 ,15 min:  [6.25, 6.194444444444444, 6.180555555555555]

# %%
loded.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	longitude = 1440 ;
# 	latitude = 721 ;
# 	time = 0 ;
#
# variables:
# 	float32 longitude(longitude) ;
# 		longitude:units = degrees_east ;
# 		longitude:long_name = longitude ;
# 	float32 latitude(latitude) ;
# 		latitude:units = degrees_north ;
# 		latitude:long_name = latitude ;
# 	datetime64[ns] time(time) ;
# 		time:long_name = time ;
# 	float32 v10(time, latitude, longitude) ;
# 		v10:units = m s**-1 ;
# 		v10:long_name = 10 metre V wind component ;
#
# // global attributes:
# 	:Conventions = CF-1.6 ;
# 	:history = 2022-07-14 14:01:09 GMT by grib_to_netcdf-2.25.1: /opt/ecmwf/mars-client/bin/grib_to_netcdf.bin -S param -o /cache/data1/adaptor.mars.internal-1657806762.467146-16033-8-e12dca0a-c8ec-405a-9f94-5781ea6dc0fe.nc /cache/tmp/e12dca0a-c8ec-405a-9f94-5781ea6dc0fe-adaptor.mars.internal-1657806279.235086-16033-9-tmp.grib ;
# }

# %%
p = loded.to_array()
p
# Out:
# <xarray.DataArray (variable: 1, time: 23, latitude: 721, longitude: 1440)>
# array([[[[-0.44204712, -0.44204712, -0.44204712, ..., -0.44204712,
#           -0.44204712, -0.44204712],
#          [ 0.7951164 ,  0.80436134,  0.8136053 , ...,  0.762763  ,
#            0.7735472 ,  0.7843323 ],
#          [ 0.8675289 ,  0.87831306,  0.8937206 , ...,  0.81668663,
#            0.8382559 ,  0.8552036 ],
#          ...,
#          [-6.2581034 , -6.265806  , -6.2765913 , ..., -6.216505  ,
#           -6.234993  , -6.2488594 ],
#          [-6.553913  , -6.5600758 , -6.5662384 , ..., -6.526181  ,
#           -6.535425  , -6.544669  ],
#          [ 0.01861572,  0.01861572,  0.01861572, ...,  0.01861572,
#            0.01861572,  0.01861572]],
#
#         [[-0.34036255, -0.34036255, -0.34036255, ..., -0.34036255,
#           -0.34036255, -0.34036255],
#          [ 0.5285797 ,  0.5378237 ,  0.54706764, ...,  0.49622536,
#            0.50701046,  0.5177946 ],
#          [ 0.6210203 ,  0.6302643 ,  0.6456709 , ...,  0.5717182 ,
#            0.5932884 ,  0.60869503],
# ...
#          [-7.123964  , -7.1347485 , -7.145533  , ..., -7.076203  ,
#           -7.094691  , -7.1116385 ],
#          [-7.162481  , -7.1686435 , -7.176347  , ..., -7.131667  ,
#           -7.142452  , -7.1532364 ],
#          [ 0.11259651,  0.11259651,  0.11259651, ...,  0.11259651,
#            0.11259651,  0.11259651]],
#
#         [[-0.3465252 , -0.3465252 , -0.3465252 , ..., -0.3465252 ,
#           -0.3465252 , -0.3465252 ],
#          [ 2.3065205 ,  2.3188457 ,  2.3327122 , ...,  2.2603016 ,
#            2.2757072 ,  2.2911148 ],
#          [ 2.5006466 ,  2.5160542 ,  2.5376225 , ...,  2.428234  ,
#            2.4590473 ,  2.4836998 ],
#          ...,
#          [-7.2934384 , -7.3026824 , -7.3150077 , ..., -7.2425957 ,
#           -7.2626247 , -7.2811127 ],
#          [-7.395123  , -7.4028263 , -7.408989  , ..., -7.3627687 ,
#           -7.3735533 , -7.3843384 ],
#          [ 0.14495087,  0.14495087,  0.14495087, ...,  0.14495087,
#            0.14495087,  0.14495087]]]], dtype=float32)
# Coordinates:
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 1990-01-01 ... 1990-01-01T22:00:00
#   * variable   (variable) object 'v10'
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-07-14 14:01:09 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
loaded2.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	longitude = 1440 ;
# 	latitude = 721 ;
# 	time = 768 ;
#
# variables:
# 	float32 longitude(longitude) ;
# 		longitude:units = degrees_east ;
# 		longitude:long_name = longitude ;
# 	float32 latitude(latitude) ;
# 		latitude:units = degrees_north ;
# 		latitude:long_name = latitude ;
# 	datetime64[ns] time(time) ;
# 		time:long_name = time ;
# 	float32 v10(time, latitude, longitude) ;
# 		v10:units = m s**-1 ;
# 		v10:long_name = 10 metre V wind component ;
#
# // global attributes:
# 	:Conventions = CF-1.6 ;
# 	:history = 2022-07-14 14:01:09 GMT by grib_to_netcdf-2.25.1: /opt/ecmwf/mars-client/bin/grib_to_netcdf.bin -S param -o /cache/data1/adaptor.mars.internal-1657806762.467146-16033-8-e12dca0a-c8ec-405a-9f94-5781ea6dc0fe.nc /cache/tmp/e12dca0a-c8ec-405a-9f94-5781ea6dc0fe-adaptor.mars.internal-1657806279.235086-16033-9-tmp.grib ;
# }

# %%
ds = xr.open_dataset(os.path.join(basePath, 'single_pressure_level', '10m_v_component_of_wind', "10m_v_component_of_wind_1990.nc"))

# %%
ds.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	longitude = 1440 ;
# 	latitude = 721 ;
# 	time = 8760 ;
#
# variables:
# 	float32 longitude(longitude) ;
# 		longitude:units = degrees_east ;
# 		longitude:long_name = longitude ;
# 	float32 latitude(latitude) ;
# 		latitude:units = degrees_north ;
# 		latitude:long_name = latitude ;
# 	datetime64[ns] time(time) ;
# 		time:long_name = time ;
# 	float32 v10(time, latitude, longitude) ;
# 		v10:units = m s**-1 ;
# 		v10:long_name = 10 metre V wind component ;
#
# // global attributes:
# 	:Conventions = CF-1.6 ;
# 	:history = 2022-07-14 20:34:17 GMT by grib_to_netcdf-2.25.1: /opt/ecmwf/mars-client/bin/grib_to_netcdf.bin -S param -o /cache/data7/adaptor.mars.internal-1657830450.5985415-23599-16-5297c509-9e3e-461b-91a9-7d5646b6ceba.nc /cache/tmp/5297c509-9e3e-461b-91a9-7d5646b6ceba-adaptor.mars.internal-1657829999.4723523-23599-23-tmp.grib ;
# }

# %%
stats = system_monitor(True,[os.getpid()],["main"])
# Out:
# RAM:
#     memory % used: 5.9
#     Used (GB): 21.782892544
#     Total available (GB): 380.29758464
#     Process memory used (GB): 0.09096515470426265
#     Process memory used :  0.3423614501953125
# CPU:
#     available cores:  72
#     util:  5.7
#     averge load over 1, 5 ,15 min:  [5.916666666666667, 6.097222222222222, 6.138888888888889]

# %%
year_loaded = ds.load()

# %%
from datetime import date
year=1980
month=1
day=25
y = date(year,month,day)

# %%
x = np.datetime64('2010-03-14T15:00:00.00')

# %%
y
# Out:
# datetime.date(1980, 1, 25)

# %%
x
# Out:
# numpy.datetime64('2010-03-14T15:00:00.000')

# %%
s_lat_long = ds.isel(latitude=0,longitude=0,hourofyear='01-01 00')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 s_lat_long = ds.isel(latitude=0,longitude=0,hourofyear='01-01 00')
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/xarray/core/dataset.py:2921, in Dataset.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    2919 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "isel")
#    2920 if any(is_fancy_indexer(idx) for idx in indexers.values()):
# -> 2921     return self._isel_fancy(indexers, drop=drop, missing_dims=missing_dims)
#    2923 # Much faster algorithm for when all indexers are ints, slices, one-dimensional
#    2924 # lists, or zero or one-dimensional np.ndarray's
#    2925 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/xarray/core/dataset.py:2964, in Dataset._isel_fancy(self, indexers, drop, missing_dims)
#    2957 def _isel_fancy(
#    2958     self,
#    2959     indexers: Mapping[Any, Any],
#    (...)
#    2962     missing_dims: ErrorOptionsWithWarn = "raise",
#    2963 ) -> Self:
# -> 2964     valid_indexers = dict(self._validate_indexers(indexers, missing_dims))
#    2966     variables: dict[Hashable, Variable] = {}
#    2967     indexes, index_variables = isel_indexes(self.xindexes, valid_indexers)
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/xarray/core/dataset.py:2710, in Dataset._validate_indexers(self, indexers, missing_dims)
#    2707 from xarray.coding.cftimeindex import CFTimeIndex
#    2708 from xarray.core.dataarray import DataArray
# -> 2710 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    2712 # all indexers should be int, slice, np.ndarrays, or Variable
#    2713 for k, v in indexers.items():
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/xarray/core/utils.py:858, in drop_dims_from_indexers(indexers, dims, missing_dims)
#     856     invalid = indexers.keys() - set(dims)
#     857     if invalid:
# --> 858         raise ValueError(
#     859             f"Dimensions {invalid} do not exist. Expected one or more of {dims}"
#     860         )
#     862     return indexers
#     864 elif missing_dims == "warn":
#     865     # don't modify input
#
# ValueError: Dimensions {'hourofyear'} do not exist. Expected one or more of Frozen({'longitude': 1440, 'latitude': 721, 'time': 376944})

# %%
ds['hourofyear'] = xr.DataArray(ds.time.dt.strftime('%m-%d %H'), coords=ds.time.coords)

# %%
s_lat_long
# Out:
# <xarray.Dataset>
# Dimensions:     ()
# Coordinates:
#     longitude   float32 0.0
#     latitude    float32 90.0
#     time        datetime64[ns] 1979-01-01
# Data variables:
#     v10         float32 dask.array<chunksize=(), meta=np.ndarray>
#     hourofyear  object '01-01 00'
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-07-14 14:01:09 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
f = "/mnt/qb/work2/goswami0/gkd965/climate/chunky/10m_v_1959-2021_hourofyear_mean_0-lat_0-long_notebook.nc"
d = xr.open_dataset(f)
d.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	hourofyear = 8784 ;
#
# variables:
# 	float32 v10(hourofyear) ;
# 		v10:units = m s**-1 ;
# 		v10:long_name = 10 metre V wind component ;
# 	float32 longitude() ;
# 		longitude:units = degrees_east ;
# 		longitude:long_name = longitude ;
# 	float32 latitude() ;
# 		latitude:units = degrees_north ;
# 		latitude:long_name = latitude ;
# 	<U8 hourofyear(hourofyear) ;
#
# // global attributes:
# 	:Conventions = CF-1.6 ;
# 	:history = 2022-07-14 14:01:09 GMT by grib_to_netcdf-2.25.1: /opt/ecmwf/mars-client/bin/grib_to_netcdf.bin -S param -o /cache/data1/adaptor.mars.internal-1657806762.467146-16033-8-e12dca0a-c8ec-405a-9f94-5781ea6dc0fe.nc /cache/tmp/e12dca0a-c8ec-405a-9f94-5781ea6dc0fe-adaptor.mars.internal-1657806279.235086-16033-9-tmp.grib ;
# }

# %%
d.isel(hourofyear=0).load()
# Out:
# <xarray.Dataset>
# Dimensions:     ()
# Coordinates:
#     longitude   float32 0.0
#     latitude    float32 90.0
#     hourofyear  <U8 '01-01 00'
# Data variables:
#     v10         float32 -0.04397
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-07-14 14:01:09 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
x = d.to_array()

# %%
x
# Out:
# <xarray.DataArray (variable: 1, hourofyear: 8784)>
# array([[-0.04396834, -0.04540868, -0.04013153, ..., -0.06221897,
#         -0.04437999, -0.0228117 ]], dtype=float32)
# Coordinates:
#     longitude   float32 0.0
#     latitude    float32 90.0
#   * hourofyear  (hourofyear) <U8 '01-01 00' '01-01 01' ... '12-31 22' '12-31 23'
#   * variable    (variable) object 'v10'
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-07-14 14:01:09 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/matplotlib/__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, _docstring, rcsetup
#     162 from matplotlib.cbook import sanitize_sequence
#     163 from matplotlib._api import MatplotlibDeprecationWarning
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/matplotlib/rcsetup.py:27
#      25 from matplotlib import _api, cbook
#      26 from matplotlib.cbook import ls_mapper
# ---> 27 from matplotlib.colors import Colormap, is_color_like
#      28 from matplotlib._fontconfig_pattern import parse_fontconfig_pattern
#      29 from matplotlib._enums import JoinStyle, CapStyle
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/matplotlib/colors.py:52
#      49 from numbers import Real
#      50 import re
# ---> 52 from PIL import Image
#      53 from PIL.PngImagePlugin import PngInfo
#      55 import matplotlib as mpl
#
# File /opt/conda/envs/model/lib/python3.11/site-packages/PIL/Image.py:82
#      73 MAX_IMAGE_PIXELS = int(1024 * 1024 * 1024 // 4 // 3)
#      76 try:
#      77     # If the _imaging C module is not present, Pillow will not load.
#      78     # Note that other modules should not refer to _imaging directly;
#      79     # import Image and use the Image.core variable instead.
#      80     # Also note that Image.core is not a publicly documented interface,
#      81     # and should be considered private and subject to change.
# ---> 82     from . import _imaging as core
#      84     if __version__ != getattr(core, "PILLOW_VERSION", None):
#      85         msg = (
#      86             "The _imaging extension was built for another version of Pillow or PIL:\n"
#      87             f"Core version: {getattr(core, 'PILLOW_VERSION', None)}\n"
#      88             f"Pillow version: {__version__}"
#      89         )
#
# ImportError: libtiff.so.5: cannot open shared object file: No such file or directory
